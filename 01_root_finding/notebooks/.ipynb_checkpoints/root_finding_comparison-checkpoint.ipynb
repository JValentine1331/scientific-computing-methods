# %% [markdown]
# ### Root-Finding Comparison Testing
#
# Compare the performance, convergence behavior, and robustness of classical root-finding algorithms:
# - Bisection
# - False Position
# - Fixed Point Iteration
# - Newton's Method
# - Secant Method

# %%
import numpy as np
import matplotlib.pyplot as plt

import os
import sys

sys.path.append(os.path.abspath(".."))

from methods.bisection import bisection
from methods.false_position import false_position
from methods.newton import newton
from methods.secant import secant
from methods.fixed_point import fixed_point
# Out:
# {'root': np.float64(0.7390851332151607), 'iterations': 4, 'converged': True, 'history': [np.float64(0.7280103614676171), np.float64(0.7390669669086738), np.float64(0.7390851331660756), np.float64(0.7390851332151607)]}
